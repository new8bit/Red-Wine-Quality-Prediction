# %% [markdown]
# # SVM

# %%
import sys
sys.path.append("..")
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from data_preprocess import load_training_data,load_test_data, normalize_features
from sklearn.metrics import accuracy_score, f1_score
import pandas as pd
import numpy as np
import time
from joblib import dump
from sklearn import svm
import joblib

# %% [markdown]
# # Train

# %%
# Load data
X_train, y_train = load_training_data('../data/train.csv')

# Normalize the features
X_train = normalize_features(X_train)

# Define the parameter grid
param_grid = {
    'C': [0.1, 1, 10, 100, 200],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid']
}

# Initialize a DataFrame to store the results
results_df = pd.DataFrame(columns=['kernel', 'C', 'gamma', 'accuracy', 'f1_score'])

# Define 5-fold cross validation test harness
kfold = KFold(n_splits=5, shuffle=True)

# Perform 5-fold cross validation
for kernel in param_grid['kernel']:
    for C in param_grid['C']:
        for gamma in param_grid['gamma']:
            start_time = time.time()

            # Create a SVM classifier using the kernel trick
            clf = svm.SVC(kernel=kernel, C=C, gamma=gamma)
            
            # Perform cross-validation manually to get the number of iterations
            cv_results = []
            f1_results = []
            for train_index, test_index in kfold.split(X_train):
                X_train_fold, X_test_fold = X_train.iloc[train_index], X_train.iloc[test_index]
                y_train_fold, y_test_fold = y_train.iloc[train_index], y_train.iloc[test_index]
                clf.fit(X_train_fold, y_train_fold)
                score = clf.score(X_test_fold, y_test_fold)
                cv_results.append(score)
                y_pred = clf.predict(X_test_fold)
                f1 = f1_score(y_test_fold, y_pred, average='weighted')
                f1_results.append(f1)

            # Save the model
            model_directory = "model_validation"
            model_filename = f"{model_directory}/model_{kernel}_{C}_{gamma}.joblib"
            dump(clf, model_filename)

            end_time = time.time()
            elapsed_time = end_time - start_time
            print(f"Kernel: {kernel}, C: {C}, Gamma: {gamma}\nCross-validation mean accuracy: {np.mean(cv_results)*100}%\nElapsed time: {elapsed_time} seconds\n")

            new_row = pd.DataFrame({
                'kernel': [kernel],
                'C': [C],
                'gamma': [gamma],
                'accuracy': [np.mean(cv_results)],
                'f1_score': [np.mean(f1_results)]
            })

            results_df = pd.concat([results_df, new_row], ignore_index=True)
# Out:
# Kernel: linear, C: 0.1, Gamma: 1
# Cross-validation mean accuracy: 57.64213645099294%
# Elapsed time: 0.10399985313415527 seconds
#
# Kernel: linear, C: 0.1, Gamma: 0.1
# Cross-validation mean accuracy: 57.91159513132607%
# Elapsed time: 0.10399961471557617 seconds
#
# Kernel: linear, C: 0.1, Gamma: 0.01
# Cross-validation mean accuracy: 57.995275464445875%
# Elapsed time: 0.09900021553039551 seconds
# C:\Users\10150\AppData\Local\Temp\ipykernel_16536\96072097.py:59: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row], ignore_index=True)
# Kernel: linear, C: 0.1, Gamma: 0.001
# Cross-validation mean accuracy: 58.706758488148616%
# Elapsed time: 0.09999966621398926 seconds
#
# Kernel: linear, C: 1, Gamma: 1
# Cross-validation mean accuracy: 58.266736066623956%
# Elapsed time: 0.13100004196166992 seconds
#
# Kernel: linear, C: 1, Gamma: 0.1
# Cross-validation mean accuracy: 58.80925688661115%
# Elapsed time: 0.1520395278930664 seconds
#
# Kernel: linear, C: 1, Gamma: 0.01
# Cross-validation mean accuracy: 58.26633568225497%
# Elapsed time: 0.12999987602233887 seconds
#
# Kernel: linear, C: 1, Gamma: 0.001
# Cross-validation mean accuracy: 57.37467969250481%
# Elapsed time: 0.12999939918518066 seconds
#
# Kernel: linear, C: 10, Gamma: 1
# Cross-validation mean accuracy: 58.89413837283792%
# Elapsed time: 0.39299964904785156 seconds
#
# Kernel: linear, C: 10, Gamma: 0.1
# Cross-validation mean accuracy: 58.174647661755294%
# Elapsed time: 0.3679995536804199 seconds
#
# Kernel: linear, C: 10, Gamma: 0.01
# Cross-validation mean accuracy: 57.640935297885974%
# Elapsed time: 0.3789999485015869 seconds
#
# Kernel: linear, C: 10, Gamma: 0.001
# Cross-validation mean accuracy: 58.80204996796925%
# Elapsed time: 0.36999964714050293 seconds
#
# Kernel: linear, C: 100, Gamma: 1
# Cross-validation mean accuracy: 58.71396540679052%
# Elapsed time: 2.9270801544189453 seconds
#
# Kernel: linear, C: 100, Gamma: 0.1
# Cross-validation mean accuracy: 57.5548526585522%
# Elapsed time: 3.223045825958252 seconds
#
# Kernel: linear, C: 100, Gamma: 0.01
# Cross-validation mean accuracy: 58.44610826393337%
# Elapsed time: 3.2936723232269287 seconds
#
# Kernel: linear, C: 100, Gamma: 0.001
# Cross-validation mean accuracy: 57.99607623318386%
# Elapsed time: 2.927304983139038 seconds
#
# Kernel: linear, C: 200, Gamma: 1
# Cross-validation mean accuracy: 57.19370595771942%
# Elapsed time: 23.997448444366455 seconds
#
# Kernel: linear, C: 200, Gamma: 0.1
# Cross-validation mean accuracy: 58.087363869314544%
# Elapsed time: 19.82735300064087 seconds
#
# Kernel: linear, C: 200, Gamma: 0.01
# Cross-validation mean accuracy: 57.641335682254955%
# Elapsed time: 28.12955331802368 seconds
#
# Kernel: linear, C: 200, Gamma: 0.001
# Cross-validation mean accuracy: 57.37187700192183%
# Elapsed time: 20.068708419799805 seconds
#
# Kernel: poly, C: 0.1, Gamma: 1
# Cross-validation mean accuracy: 54.959160794362596%
# Elapsed time: 0.6249992847442627 seconds
#
# Kernel: poly, C: 0.1, Gamma: 0.1
# Cross-validation mean accuracy: 56.56830557335042%
# Elapsed time: 0.11500000953674316 seconds
#
# Kernel: poly, C: 0.1, Gamma: 0.01
# Cross-validation mean accuracy: 41.550288276745675%
# Elapsed time: 0.10299944877624512 seconds
#
# Kernel: poly, C: 0.1, Gamma: 0.001
# Cross-validation mean accuracy: 39.592809096732864%
# Elapsed time: 0.0989997386932373 seconds
#
# Kernel: poly, C: 1, Gamma: 1
# Cross-validation mean accuracy: 56.65959320948111%
# Elapsed time: 3.638998031616211 seconds
#
# Kernel: poly, C: 1, Gamma: 0.1
# Cross-validation mean accuracy: 58.267536835361945%
# Elapsed time: 0.1230015754699707 seconds
#
# Kernel: poly, C: 1, Gamma: 0.01
# Cross-validation mean accuracy: 40.39157591287637%
# Elapsed time: 0.10599994659423828 seconds
#
# Kernel: poly, C: 1, Gamma: 0.001
# Cross-validation mean accuracy: 41.556294042280584%
# Elapsed time: 0.09774923324584961 seconds
#
# Kernel: poly, C: 10, Gamma: 1
# Cross-validation mean accuracy: 57.198910954516336%
# Elapsed time: 15.816229104995728 seconds
#
# Kernel: poly, C: 10, Gamma: 0.1
# Cross-validation mean accuracy: 58.27234144778988%
# Elapsed time: 0.1849994659423828 seconds
#
# Kernel: poly, C: 10, Gamma: 0.01
# Cross-validation mean accuracy: 42.17889173606662%
# Elapsed time: 0.1100003719329834 seconds
#
# Kernel: poly, C: 10, Gamma: 0.001
# Cross-validation mean accuracy: 41.55469250480461%
# Elapsed time: 0.09800004959106445 seconds
#
# Kernel: poly, C: 100, Gamma: 1
# Cross-validation mean accuracy: 57.104420243433694%
# Elapsed time: 58.55748391151428 seconds
#
# Kernel: poly, C: 100, Gamma: 0.1
# Cross-validation mean accuracy: 56.21196348494555%
# Elapsed time: 0.6595468521118164 seconds
#
# Kernel: poly, C: 100, Gamma: 0.01
# Cross-validation mean accuracy: 55.76353299167201%
# Elapsed time: 0.11095547676086426 seconds
#
# Kernel: poly, C: 100, Gamma: 0.001
# Cross-validation mean accuracy: 41.555893657911604%
# Elapsed time: 0.10100007057189941 seconds
#
# Kernel: poly, C: 200, Gamma: 1
# Cross-validation mean accuracy: 56.11947469570788%
# Elapsed time: 86.41785526275635 seconds
#
# Kernel: poly, C: 200, Gamma: 0.1
# Cross-validation mean accuracy: 58.89333760409994%
# Elapsed time: 0.987999439239502 seconds
#
# Kernel: poly, C: 200, Gamma: 0.01
# Cross-validation mean accuracy: 57.46276425368353%
# Elapsed time: 0.11400032043457031 seconds
#
# Kernel: poly, C: 200, Gamma: 0.001
# Cross-validation mean accuracy: 41.55789557975657%
# Elapsed time: 0.10599946975708008 seconds
#
# Kernel: rbf, C: 0.1, Gamma: 1
# Cross-validation mean accuracy: 39.769378603459316%
# Elapsed time: 0.26000046730041504 seconds
#
# Kernel: rbf, C: 0.1, Gamma: 0.1
# Cross-validation mean accuracy: 58.44570787956439%
# Elapsed time: 0.1809992790222168 seconds
#
# Kernel: rbf, C: 0.1, Gamma: 0.01
# Cross-validation mean accuracy: 56.39333760409993%
# Elapsed time: 0.18200039863586426 seconds
#
# Kernel: rbf, C: 0.1, Gamma: 0.001
# Cross-validation mean accuracy: 41.555893657911604%
# Elapsed time: 0.17999982833862305 seconds
#
# Kernel: rbf, C: 1, Gamma: 1
# Cross-validation mean accuracy: 63.53779628443306%
# Elapsed time: 0.2790029048919678 seconds
#
# Kernel: rbf, C: 1, Gamma: 0.1
# Cross-validation mean accuracy: 62.6457399103139%
# Elapsed time: 0.1749436855316162 seconds
#
# Kernel: rbf, C: 1, Gamma: 0.01
# Cross-validation mean accuracy: 58.00088084561178%
# Elapsed time: 0.17099952697753906 seconds
#
# Kernel: rbf, C: 1, Gamma: 0.001
# Cross-validation mean accuracy: 54.868673926969905%
# Elapsed time: 0.1830000877380371 seconds
#
# Kernel: rbf, C: 10, Gamma: 1
# Cross-validation mean accuracy: 63.36162716207559%
# Elapsed time: 0.2799997329711914 seconds
#
# Kernel: rbf, C: 10, Gamma: 0.1
# Cross-validation mean accuracy: 61.74687700192185%
# Elapsed time: 0.19632506370544434 seconds
#
# Kernel: rbf, C: 10, Gamma: 0.01
# Cross-validation mean accuracy: 59.51833760409993%
# Elapsed time: 0.1775989532470703 seconds
#
# Kernel: rbf, C: 10, Gamma: 0.001
# Cross-validation mean accuracy: 58.264333760410004%
# Elapsed time: 0.17895865440368652 seconds
#
# Kernel: rbf, C: 100, Gamma: 1
# Cross-validation mean accuracy: 62.46957078795643%
# Elapsed time: 0.2838873863220215 seconds
#
# Kernel: rbf, C: 100, Gamma: 0.1
# Cross-validation mean accuracy: 58.44690903267136%
# Elapsed time: 0.28679323196411133 seconds
#
# Kernel: rbf, C: 100, Gamma: 0.01
# Cross-validation mean accuracy: 60.3191063420884%
# Elapsed time: 0.2219994068145752 seconds
#
# Kernel: rbf, C: 100, Gamma: 0.001
# Cross-validation mean accuracy: 57.90598975016016%
# Elapsed time: 0.19299983978271484 seconds
#
# Kernel: rbf, C: 200, Gamma: 1
# Cross-validation mean accuracy: 60.50448430493274%
# Elapsed time: 0.28299951553344727 seconds
#
# Kernel: rbf, C: 200, Gamma: 0.1
# Cross-validation mean accuracy: 56.74527546444587%
# Elapsed time: 0.3209991455078125 seconds
#
# Kernel: rbf, C: 200, Gamma: 0.01
# Cross-validation mean accuracy: 60.59096732863549%
# Elapsed time: 0.26999998092651367 seconds
#
# Kernel: rbf, C: 200, Gamma: 0.001
# Cross-validation mean accuracy: 58.18265534913516%
# Elapsed time: 0.20199942588806152 seconds
#
# Kernel: sigmoid, C: 0.1, Gamma: 1
# Cross-validation mean accuracy: 46.384529147982065%
# Elapsed time: 0.15900015830993652 seconds
#
# Kernel: sigmoid, C: 0.1, Gamma: 0.1
# Cross-validation mean accuracy: 56.477418321588736%
# Elapsed time: 0.14400029182434082 seconds
#
# Kernel: sigmoid, C: 0.1, Gamma: 0.01
# Cross-validation mean accuracy: 53.707158872517624%
# Elapsed time: 0.16200017929077148 seconds
#
# Kernel: sigmoid, C: 0.1, Gamma: 0.001
# Cross-validation mean accuracy: 40.03723574631646%
# Elapsed time: 0.1510000228881836 seconds
#
# Kernel: sigmoid, C: 1, Gamma: 1
# Cross-validation mean accuracy: 46.47381486226777%
# Elapsed time: 0.14499950408935547 seconds
#
# Kernel: sigmoid, C: 1, Gamma: 0.1
# Cross-validation mean accuracy: 50.22741832158872%
# Elapsed time: 0.12399983406066895 seconds
#
# Kernel: sigmoid, C: 1, Gamma: 0.01
# Cross-validation mean accuracy: 57.99727738629083%
# Elapsed time: 0.1549999713897705 seconds
#
# Kernel: sigmoid, C: 1, Gamma: 0.001
# Cross-validation mean accuracy: 51.64958360025624%
# Elapsed time: 0.15799999237060547 seconds
#
# Kernel: sigmoid, C: 10, Gamma: 1
# Cross-validation mean accuracy: 41.46620755925689%
# Elapsed time: 0.1379997730255127 seconds
#
# Kernel: sigmoid, C: 10, Gamma: 0.1
# Cross-validation mean accuracy: 48.70075272261371%
# Elapsed time: 0.10699963569641113 seconds
#
# Kernel: sigmoid, C: 10, Gamma: 0.01
# Cross-validation mean accuracy: 58.53619474695707%
# Elapsed time: 0.1529998779296875 seconds
#
# Kernel: sigmoid, C: 10, Gamma: 0.001
# Cross-validation mean accuracy: 58.35882447149263%
# Elapsed time: 0.1510002613067627 seconds
#
# Kernel: sigmoid, C: 100, Gamma: 1
# Cross-validation mean accuracy: 43.52178090967329%
# Elapsed time: 0.14099979400634766 seconds
#
# Kernel: sigmoid, C: 100, Gamma: 0.1
# Cross-validation mean accuracy: 48.164638052530435%
# Elapsed time: 0.10399985313415527 seconds
#
# Kernel: sigmoid, C: 100, Gamma: 0.01
# Cross-validation mean accuracy: 55.22661755285073%
# Elapsed time: 0.15899991989135742 seconds
#
# Kernel: sigmoid, C: 100, Gamma: 0.001
# Cross-validation mean accuracy: 58.00248238308776%
# Elapsed time: 0.21000003814697266 seconds
#
# Kernel: sigmoid, C: 200, Gamma: 1
# Cross-validation mean accuracy: 44.325752722613714%
# Elapsed time: 0.13900017738342285 seconds
#
# Kernel: sigmoid, C: 200, Gamma: 0.1
# Cross-validation mean accuracy: 48.255925688661115%
# Elapsed time: 0.10299968719482422 seconds
#
# Kernel: sigmoid, C: 200, Gamma: 0.01
# Cross-validation mean accuracy: 52.28219090326714%
# Elapsed time: 0.1549997329711914 seconds
#
# Kernel: sigmoid, C: 200, Gamma: 0.001
# Cross-validation mean accuracy: 58.17384689301729%
# Elapsed time: 0.2669999599456787 seconds

# %% [markdown]
# ## The Best Parameters

# %%
# Sort the results by accuracy in descending order
sorted_results = results_df.sort_values(by='accuracy', ascending=False)

# Print the best parameters and corresponding accuracy
best_params = sorted_results.iloc[0]
print(f"Best parameters: Kernel={best_params['kernel']}, C={best_params['C']}, Gamma={best_params['gamma']}")
print(f"Best accuracy: {best_params['accuracy']*100}%")
# Out:
# Best parameters: Kernel=rbf, C=1.0, Gamma=1
# Best accuracy: 63.53779628443306%

# %% [markdown]
# ## Train the Model

# %%
# Find the parameters with the highest accuracy
best_params = results_df.loc[results_df['accuracy'].idxmax()]

# Print the best parameters
print(f"Best parameters:\nKernel: {best_params['kernel']}, C: {best_params['C']}, Gamma: {best_params['gamma']}\nAccuracy: {best_params['accuracy']}, F1 Score: {best_params['f1_score']}")

# Train the model with the best parameters on the full training set
best_clf = svm.SVC(kernel=best_params['kernel'], C=best_params['C'], gamma=best_params['gamma'])
best_clf.fit(X_train, y_train)

# Save the best model
best_model_filename = "model/svm.joblib"
dump(best_clf, best_model_filename)
# Out:
# Best parameters:
# Kernel: rbf, C: 1.0, Gamma: 1
# Accuracy: 0.6353779628443306, F1 Score: 0.6024524503005982
# ['model_validation/best_model_rbf_1.0_1.joblib']

# %% [markdown]
# ## Predict

# %%
# Load the model
best_model_filename = f"model_validation/best_model_{best_params['kernel']}_{best_params['C']}_{best_params['gamma']}.joblib"
best_clf = joblib.load(best_model_filename)

# Load the test data
X_test, y_test = load_test_data('../data/test.csv')

# Normalize the test data
X_test_normalized = normalize_features(X_test)

# Predict the labels of the test set
y_pred = best_clf.predict(X_test_normalized)

# Calculate the accuracy of the model on the test set
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.6416666666666667
