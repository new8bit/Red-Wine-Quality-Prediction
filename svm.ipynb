# %% [markdown]
# # SVM

# %%
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from data_preprocess import load_training_data,load_test_data, normalize_features
from sklearn.metrics import accuracy_score, f1_score
import pandas as pd
import numpy as np
import time
from joblib import dump
from sklearn import svm
import joblib

# %% [markdown]
# # Training

# %%
# Load data
X_train, y_train = load_training_data('data/train.csv')

# Normalize the features
X_train = normalize_features(X_train)

# Define the parameter grid
param_grid = {
    'C': [0.1, 1, 10, 100, 200],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid']
}

# Initialize a DataFrame to store the results
results_df = pd.DataFrame(columns=['kernel', 'C', 'gamma', 'accuracy', 'f1_score'])

# Define 5-fold cross validation test harness
kfold = KFold(n_splits=5, shuffle=True)

# Perform 5-fold cross validation
for kernel in param_grid['kernel']:
    for C in param_grid['C']:
        for gamma in param_grid['gamma']:
            start_time = time.time()

            # Create a SVM classifier using the kernel trick
            clf = svm.SVC(kernel=kernel, C=C, gamma=gamma)
            
            # Perform cross-validation manually to get the number of iterations
            cv_results = []
            f1_results = []
            for train_index, test_index in kfold.split(X_train):
                X_train_fold, X_test_fold = X_train.iloc[train_index], X_train.iloc[test_index]
                y_train_fold, y_test_fold = y_train.iloc[train_index], y_train.iloc[test_index]
                clf.fit(X_train_fold, y_train_fold)
                score = clf.score(X_test_fold, y_test_fold)
                cv_results.append(score)
                y_pred = clf.predict(X_test_fold)
                f1 = f1_score(y_test_fold, y_pred, average='weighted')
                f1_results.append(f1)

            # Save the model
            model_filename = "models/svm.joblib"
            dump(clf, model_filename)

            end_time = time.time()
            elapsed_time = end_time - start_time
            print(f"Kernel: {kernel}, C: {C}, Gamma: {gamma}\nCross-validation mean accuracy: {np.mean(cv_results)*100}%\nElapsed time: {elapsed_time} seconds\n")

            new_row = pd.DataFrame({
                'kernel': [kernel],
                'C': [C],
                'gamma': [gamma],
                'accuracy': [np.mean(cv_results)],
                'f1_score': [np.mean(f1_results)]
            })

            results_df = pd.concat([results_df, new_row], ignore_index=True)
# Out:
# Kernel: linear, C: 0.1, Gamma: 1
# Cross-validation mean accuracy: 58.53419282511211%
# Elapsed time: 0.8874905109405518 seconds
#
# Kernel: linear, C: 0.1, Gamma: 0.1
# Cross-validation mean accuracy: 58.53539397821908%
# Elapsed time: 0.4089205265045166 seconds
#
# Kernel: linear, C: 0.1, Gamma: 0.01
# Cross-validation mean accuracy: 57.9103939782191%
# Elapsed time: 0.44971346855163574 seconds
#
# Kernel: linear, C: 0.1, Gamma: 0.001
# Cross-validation mean accuracy: 58.271540679051895%
# Elapsed time: 0.43506765365600586 seconds
#
# Kernel: linear, C: 1, Gamma: 1
# Cross-validation mean accuracy: 57.641335682254955%
# Elapsed time: 0.8371241092681885 seconds
#
# Kernel: linear, C: 1, Gamma: 0.1
# Cross-validation mean accuracy: 57.37948430493274%
# Elapsed time: 0.6830554008483887 seconds
#
# Kernel: linear, C: 1, Gamma: 0.01
# Cross-validation mean accuracy: 57.72661755285073%
# Elapsed time: 0.8625984191894531 seconds
#
# Kernel: linear, C: 1, Gamma: 0.001
# Cross-validation mean accuracy: 58.71356502242152%
# Elapsed time: 0.8040142059326172 seconds
#
# Kernel: linear, C: 10, Gamma: 1
# Cross-validation mean accuracy: 57.99967969250481%
# Elapsed time: 1.5736818313598633 seconds
#
# Kernel: linear, C: 10, Gamma: 0.1
# Cross-validation mean accuracy: 57.01473414477898%
# Elapsed time: 1.828489065170288 seconds
#
# Kernel: linear, C: 10, Gamma: 0.01
# Cross-validation mean accuracy: 58.62347853939782%
# Elapsed time: 1.9242632389068604 seconds
#
# Kernel: linear, C: 10, Gamma: 0.001
# Cross-validation mean accuracy: 58.62307815502883%
# Elapsed time: 2.064452886581421 seconds
#
# Kernel: linear, C: 100, Gamma: 1
# Cross-validation mean accuracy: 58.356422165278666%
# Elapsed time: 14.670767307281494 seconds
#
# Kernel: linear, C: 100, Gamma: 0.1
# Cross-validation mean accuracy: 58.08376040999359%
# Elapsed time: 12.07248568534851 seconds
#
# Kernel: linear, C: 100, Gamma: 0.01
# Cross-validation mean accuracy: 58.985826393337604%
# Elapsed time: 17.499966382980347 seconds
#
# Kernel: linear, C: 100, Gamma: 0.001
# Cross-validation mean accuracy: 58.087764253683524%
# Elapsed time: 10.698705196380615 seconds
#
# Kernel: linear, C: 200, Gamma: 1
# Cross-validation mean accuracy: 57.37548046124278%
# Elapsed time: 81.58302569389343 seconds
#
# Kernel: linear, C: 200, Gamma: 0.1
# Cross-validation mean accuracy: 57.90598975016016%
# Elapsed time: 77.4850103855133 seconds
#
# Kernel: linear, C: 200, Gamma: 0.01
# Cross-validation mean accuracy: 58.35802370275465%
# Elapsed time: 61.782400131225586 seconds
#
# Kernel: linear, C: 200, Gamma: 0.001
# Cross-validation mean accuracy: 57.285794362588085%
# Elapsed time: 59.114378929138184 seconds
#
# Kernel: poly, C: 0.1, Gamma: 1
# Cross-validation mean accuracy: 57.90799167200513%
# Elapsed time: 2.4933722019195557 seconds
#
# Kernel: poly, C: 0.1, Gamma: 0.1
# Cross-validation mean accuracy: 55.765935297885974%
# Elapsed time: 0.623687744140625 seconds
#
# Kernel: poly, C: 0.1, Gamma: 0.01
# Cross-validation mean accuracy: 37.35065663036515%
# Elapsed time: 0.733771562576294 seconds
#
# Kernel: poly, C: 0.1, Gamma: 0.001
# Cross-validation mean accuracy: 40.12572069186419%
# Elapsed time: 0.551520586013794 seconds
#
# Kernel: poly, C: 1, Gamma: 1
# Cross-validation mean accuracy: 56.657991672005124%
# Elapsed time: 11.04697036743164 seconds
#
# Kernel: poly, C: 1, Gamma: 0.1
# Cross-validation mean accuracy: 59.96716848174246%
# Elapsed time: 0.5511729717254639 seconds
#
# Kernel: poly, C: 1, Gamma: 0.01
# Cross-validation mean accuracy: 39.76537475976938%
# Elapsed time: 0.580657958984375 seconds
#
# Kernel: poly, C: 1, Gamma: 0.001
# Cross-validation mean accuracy: 38.33960602178092%
# Elapsed time: 0.5158500671386719 seconds
#
# Kernel: poly, C: 10, Gamma: 1
# Cross-validation mean accuracy: 57.278987828315174%
# Elapsed time: 90.18204736709595 seconds
#
# Kernel: poly, C: 10, Gamma: 0.1
# Cross-validation mean accuracy: 58.00088084561178%
# Elapsed time: 1.2836575508117676 seconds
#
# Kernel: poly, C: 10, Gamma: 0.01
# Cross-validation mean accuracy: 40.83680333119795%
# Elapsed time: 1.06357741355896 seconds
#
# Kernel: poly, C: 10, Gamma: 0.001
# Cross-validation mean accuracy: 41.555893657911604%
# Elapsed time: 0.5845139026641846 seconds
#
# Kernel: poly, C: 100, Gamma: 1
# Cross-validation mean accuracy: 59.25088084561179%
# Elapsed time: 342.52030515670776 seconds
#
# Kernel: poly, C: 100, Gamma: 0.1
# Cross-validation mean accuracy: 54.87107623318386%
# Elapsed time: 1.808950424194336 seconds
#
# Kernel: poly, C: 100, Gamma: 0.01
# Cross-validation mean accuracy: 55.04964766175527%
# Elapsed time: 0.3464078903198242 seconds
#
# Kernel: poly, C: 100, Gamma: 0.001
# Cross-validation mean accuracy: 41.556694426649585%
# Elapsed time: 0.3923523426055908 seconds
#
# Kernel: poly, C: 200, Gamma: 1
# Cross-validation mean accuracy: 56.122677770659834%
# Elapsed time: 286.67347145080566 seconds
#
# Kernel: poly, C: 200, Gamma: 0.1
# Cross-validation mean accuracy: 58.264734144778984%
# Elapsed time: 6.211188793182373 seconds
#
# Kernel: poly, C: 200, Gamma: 0.01
# Cross-validation mean accuracy: 58.17664958360026%
# Elapsed time: 0.721365213394165 seconds
#
# Kernel: poly, C: 200, Gamma: 0.001
# Cross-validation mean accuracy: 39.589205637411915%
# Elapsed time: 0.8048610687255859 seconds
#
# Kernel: rbf, C: 0.1, Gamma: 1
# Cross-validation mean accuracy: 39.5904067905189%
# Elapsed time: 1.9712333679199219 seconds
#
# Kernel: rbf, C: 0.1, Gamma: 0.1
# Cross-validation mean accuracy: 58.89333760409994%
# Elapsed time: 1.2418887615203857 seconds
#
# Kernel: rbf, C: 0.1, Gamma: 0.01
# Cross-validation mean accuracy: 56.65398782831519%
# Elapsed time: 1.331308126449585 seconds
#
# Kernel: rbf, C: 0.1, Gamma: 0.001
# Cross-validation mean accuracy: 41.555893657911604%
# Elapsed time: 1.2355232238769531 seconds
#
# Kernel: rbf, C: 1, Gamma: 1
# Cross-validation mean accuracy: 62.46316463805254%
# Elapsed time: 2.194028615951538 seconds
#
# Kernel: rbf, C: 1, Gamma: 0.1
# Cross-validation mean accuracy: 61.65959320948111%
# Elapsed time: 1.3016088008880615 seconds
#
# Kernel: rbf, C: 1, Gamma: 0.01
# Cross-validation mean accuracy: 58.62307815502883%
# Elapsed time: 1.5359094142913818 seconds
#
# Kernel: rbf, C: 1, Gamma: 0.001
# Cross-validation mean accuracy: 56.20555733504165%
# Elapsed time: 1.3757388591766357 seconds
#
# Kernel: rbf, C: 10, Gamma: 1
# Cross-validation mean accuracy: 61.48222293401665%
# Elapsed time: 2.298090934753418 seconds
#
# Kernel: rbf, C: 10, Gamma: 0.1
# Cross-validation mean accuracy: 61.30805573350416%
# Elapsed time: 1.2916233539581299 seconds
#
# Kernel: rbf, C: 10, Gamma: 0.01
# Cross-validation mean accuracy: 58.80204996796925%
# Elapsed time: 1.437917947769165 seconds
#
# Kernel: rbf, C: 10, Gamma: 0.001
# Cross-validation mean accuracy: 57.91079436258808%
# Elapsed time: 1.3026139736175537 seconds
#
# Kernel: rbf, C: 100, Gamma: 1
# Cross-validation mean accuracy: 61.665198590647016%
# Elapsed time: 2.090461492538452 seconds
#
# Kernel: rbf, C: 100, Gamma: 0.1
# Cross-validation mean accuracy: 59.25408392056374%
# Elapsed time: 1.7717950344085693 seconds
#
# Kernel: rbf, C: 100, Gamma: 0.01
# Cross-validation mean accuracy: 60.23022101217169%
# Elapsed time: 1.4287493228912354 seconds
#
# Kernel: rbf, C: 100, Gamma: 0.001
# Cross-validation mean accuracy: 58.8953395259449%
# Elapsed time: 1.3627803325653076 seconds
#
# Kernel: rbf, C: 200, Gamma: 1
# Cross-validation mean accuracy: 60.32591287636131%
# Elapsed time: 2.167853355407715 seconds
#
# Kernel: rbf, C: 200, Gamma: 0.1
# Cross-validation mean accuracy: 59.69610826393337%
# Elapsed time: 2.0840320587158203 seconds
#
# Kernel: rbf, C: 200, Gamma: 0.01
# Cross-validation mean accuracy: 59.698910954516336%
# Elapsed time: 1.7615351676940918 seconds
#
# Kernel: rbf, C: 200, Gamma: 0.001
# Cross-validation mean accuracy: 58.3544202434337%
# Elapsed time: 1.38034987449646 seconds
#
# Kernel: sigmoid, C: 0.1, Gamma: 1
# Cross-validation mean accuracy: 44.242472773862914%
# Elapsed time: 1.0478017330169678 seconds
#
# Kernel: sigmoid, C: 0.1, Gamma: 0.1
# Cross-validation mean accuracy: 56.65879244074311%
# Elapsed time: 0.9848997592926025 seconds
#
# Kernel: sigmoid, C: 0.1, Gamma: 0.01
# Cross-validation mean accuracy: 52.19090326713645%
# Elapsed time: 1.1394329071044922 seconds
#
# Kernel: sigmoid, C: 0.1, Gamma: 0.001
# Cross-validation mean accuracy: 39.85986547085202%
# Elapsed time: 0.9099912643432617 seconds
#
# Kernel: sigmoid, C: 1, Gamma: 1
# Cross-validation mean accuracy: 45.84200832799487%
# Elapsed time: 0.964087963104248 seconds
#
# Kernel: sigmoid, C: 1, Gamma: 0.1
# Cross-validation mean accuracy: 51.75168161434978%
# Elapsed time: 0.816025972366333 seconds
#
# Kernel: sigmoid, C: 1, Gamma: 0.01
# Cross-validation mean accuracy: 58.08496156310057%
# Elapsed time: 0.9913206100463867 seconds
#
# Kernel: sigmoid, C: 1, Gamma: 0.001
# Cross-validation mean accuracy: 53.43930172966047%
# Elapsed time: 0.9188153743743896 seconds
#
# Kernel: sigmoid, C: 10, Gamma: 1
# Cross-validation mean accuracy: 43.342809096732864%
# Elapsed time: 1.0794262886047363 seconds
#
# Kernel: sigmoid, C: 10, Gamma: 0.1
# Cross-validation mean accuracy: 47.633728379244076%
# Elapsed time: 0.6274807453155518 seconds
#
# Kernel: sigmoid, C: 10, Gamma: 0.01
# Cross-validation mean accuracy: 57.19770980140936%
# Elapsed time: 0.9517428874969482 seconds
#
# Kernel: sigmoid, C: 10, Gamma: 0.001
# Cross-validation mean accuracy: 58.35522101217169%
# Elapsed time: 0.886143684387207 seconds
#
# Kernel: sigmoid, C: 100, Gamma: 1
# Cross-validation mean accuracy: 45.04083920563741%
# Elapsed time: 1.0607850551605225 seconds
#
# Kernel: sigmoid, C: 100, Gamma: 0.1
# Cross-validation mean accuracy: 45.12972453555413%
# Elapsed time: 0.5961859226226807 seconds
#
# Kernel: sigmoid, C: 100, Gamma: 0.01
# Cross-validation mean accuracy: 54.87107623318386%
# Elapsed time: 0.9940493106842041 seconds
#
# Kernel: sigmoid, C: 100, Gamma: 0.001
# Cross-validation mean accuracy: 58.35682254964766%
# Elapsed time: 1.384361743927002 seconds
#
# Kernel: sigmoid, C: 200, Gamma: 1
# Cross-validation mean accuracy: 43.60826393337604%
# Elapsed time: 0.9606006145477295 seconds
#
# Kernel: sigmoid, C: 200, Gamma: 0.1
# Cross-validation mean accuracy: 44.859865470852014%
# Elapsed time: 0.6160802841186523 seconds
#
# Kernel: sigmoid, C: 200, Gamma: 0.01
# Cross-validation mean accuracy: 51.386531069827036%
# Elapsed time: 0.9131767749786377 seconds
#
# Kernel: sigmoid, C: 200, Gamma: 0.001
# Cross-validation mean accuracy: 58.892937219730946%
# Elapsed time: 1.7027063369750977 seconds

# %% [markdown]
# ## The Best Parameters

# %%
# Sort the results by accuracy in descending order
sorted_results = results_df.sort_values(by='accuracy', ascending=False)

# Print the best parameters and corresponding accuracy
best_params = sorted_results.iloc[0]
print(f"Best parameters: Kernel={best_params['kernel']}, C={best_params['C']}, Gamma={best_params['gamma']}")
print(f"Best accuracy: {best_params['accuracy']*100}%")
# Out:
# Best parameters: Kernel=rbf, C=1.0, Gamma=1
# Best accuracy: 62.46316463805254%

# %% [markdown]
# ## Train the Model

# %%
# Find the parameters with the highest accuracy
best_params = results_df.loc[results_df['accuracy'].idxmax()]

# Print the best parameters
print(f"Best parameters:\nKernel: {best_params['kernel']}, C: {best_params['C']}, Gamma: {best_params['gamma']}\nAccuracy: {best_params['accuracy']}, F1 Score: {best_params['f1_score']}")

# Train the model with the best parameters on the full training set
best_clf = svm.SVC(kernel=best_params['kernel'], C=best_params['C'], gamma=best_params['gamma'])
best_clf.fit(X_train, y_train)

# Save the best model
best_model_filename = "models/svm.joblib"
dump(best_clf, best_model_filename)
# Out:
# Best parameters:
# Kernel: rbf, C: 1.0, Gamma: 1
# Accuracy: 0.6246316463805254, F1 Score: 0.5931782391006815
# ['models/svm.joblib']

# %% [markdown]
# ## Predict

# %%
# Load the model
best_model_filename = f"models/svm.joblib"
best_clf = joblib.load(best_model_filename)

# Load the test data
X_test, y_test = load_test_data('data/test.csv')

# Normalize the test data
X_test_normalized = normalize_features(X_test)

# Predict the labels of the test set
y_pred = best_clf.predict(X_test_normalized)

# Calculate the accuracy of the model on the test set
accuracy = accuracy_score(y_test, y_pred)

# Calculate the F1 score of the model on the test set
f1 = f1_score(y_test, y_pred, average='weighted')

# Print the accuracy
print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.6416666666666667
# F1 Score: 0.6288297020605569
