# %% [markdown]
# # KNN

# %%
import os
import sys
import numpy as np
import time
import joblib
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
sys.path.append("..")
from data_preprocess import load_training_data

def remove_outliers(df, feature_names):
    clean_df = df.copy()
    for feature in feature_names:
        Q1 = clean_df[feature].quantile(0.1)
        Q3 = clean_df[feature].quantile(0.9)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        clean_df = clean_df[(clean_df[feature] >= lower_bound) & (clean_df[feature] <= upper_bound)]
    return clean_df

# Get the data
X_train, y_train = load_training_data('data/train.csv')

# Select only the specified features
# alcohol
# sulphates
# total sulfur dioxide
# volatile acidity
# density
# chlorides
# residual sugar
# fixed acidity
# pH
# citric acid
# free sulfur dioxide
features = ['alcohol', 'sulphates', 'total sulfur dioxide', 'volatile acidity']
X_train = X_train[features]

#X_train = remove_outliers(X_train, features)

# Standardize features instead of just normalizing
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# Initialize variables
n_neighbors_values = [5, 10, 15, 20, 25, 50, 75, 100, 150]
#n_neighbors_values = [3, 5, 7]
weights_options = ['uniform', 'distance']
algorithm_options = ['auto', 'ball_tree', 'kd_tree', 'brute']
distance_options = [1,2]
results = {}
best_model = None
best_score = -np.inf
best_config = None

# Define 5-fold cross validation test harness
kfold = KFold(n_splits=5, shuffle=True)

# Perform 5-fold cross validation
for n_neighbors in n_neighbors_values:
    for weights in weights_options:
        for algorithm in algorithm_options:
            for p in distance_options:
                start_time = time.time()

                # Define the model
                model = KNeighborsClassifier(n_neighbors=n_neighbors, weights=weights, algorithm=algorithm, p=p)

                # Perform cross-validation manually to get the accuracy
                cv_results = []
                for train_index, test_index in kfold.split(X_train):
                    X_train_fold, X_test_fold = X_train[train_index], X_train[test_index]
                    y_train_fold, y_test_fold = y_train[train_index], y_train[test_index]
                    model.fit(X_train_fold, y_train_fold)
                    score = model.score(X_test_fold, y_test_fold)
                    cv_results.append(score)

                # Average cross-validation score
                average_score = np.mean(cv_results)
                end_time = time.time()
                elapsed_time = end_time - start_time
                config = (n_neighbors, weights, algorithm, p)

                # Update best model if current model is better
                if average_score > best_score:
                    best_score = average_score
                    best_model = model
                    best_config = config

                # Save the model
                # model_directory = "model_validation"
                # if not os.path.exists(model_directory):
                #     os.makedirs(model_directory)
                # model_filename = f"{model_directory}/knn_model_{n_neighbors}_{weights}_{algorithm}_{p}.joblib"
                # joblib.dump(model, model_filename)

                print("Config: {}\nCross-validation mean accuracy: {:.2f}%\nElapsed time: {:.2f} seconds\n".format(
                    config, average_score * 100, elapsed_time))

                results[config] = average_score
# Out:
# Config: (5, 'uniform', 'auto', 1)
# Cross-validation mean accuracy: 38.16%
# Elapsed time: 0.03 seconds
#
# Config: (5, 'uniform', 'auto', 2)
# Cross-validation mean accuracy: 39.87%
# Elapsed time: 0.03 seconds
#
# Config: (5, 'uniform', 'ball_tree', 1)
# Cross-validation mean accuracy: 41.14%
# Elapsed time: 0.03 seconds
#
# Config: (5, 'uniform', 'ball_tree', 2)
# Cross-validation mean accuracy: 40.50%
# Elapsed time: 0.03 seconds
#
# Config: (5, 'uniform', 'kd_tree', 1)
# Cross-validation mean accuracy: 37.44%
# Elapsed time: 0.03 seconds
#
# Config: (5, 'uniform', 'kd_tree', 2)
# Cross-validation mean accuracy: 40.87%
# Elapsed time: 0.02 seconds
#
# Config: (5, 'uniform', 'brute', 1)
# Cross-validation mean accuracy: 40.41%
# Elapsed time: 0.03 seconds
#
# Config: (5, 'uniform', 'brute', 2)
# Cross-validation mean accuracy: 38.97%
# Elapsed time: 0.04 seconds
#
# Config: (5, 'distance', 'auto', 1)
# Cross-validation mean accuracy: 38.62%
# Elapsed time: 0.01 seconds
#
# Config: (5, 'distance', 'auto', 2)
# Cross-validation mean accuracy: 37.53%
# Elapsed time: 0.01 seconds
#
# Config: (5, 'distance', 'ball_tree', 1)
# Cross-validation mean accuracy: 36.10%
# Elapsed time: 0.01 seconds
#
# Config: (5, 'distance', 'ball_tree', 2)
# Cross-validation mean accuracy: 38.53%
# Elapsed time: 0.01 seconds
#
# Config: (5, 'distance', 'kd_tree', 1)
# Cross-validation mean accuracy: 37.81%
# Elapsed time: 0.01 seconds
#
# Config: (5, 'distance', 'kd_tree', 2)
# Cross-validation mean accuracy: 38.17%
# Elapsed time: 0.01 seconds
#
# Config: (5, 'distance', 'brute', 1)
# Cross-validation mean accuracy: 38.16%
# Elapsed time: 0.02 seconds
#
# Config: (5, 'distance', 'brute', 2)
# Cross-validation mean accuracy: 36.01%
# Elapsed time: 0.03 seconds
#
# Config: (10, 'uniform', 'auto', 1)
# Cross-validation mean accuracy: 41.13%
# Elapsed time: 0.03 seconds
#
# Config: (10, 'uniform', 'auto', 2)
# Cross-validation mean accuracy: 42.93%
# Elapsed time: 0.03 seconds
#
# Config: (10, 'uniform', 'ball_tree', 1)
# Cross-validation mean accuracy: 42.57%
# Elapsed time: 0.03 seconds
#
# Config: (10, 'uniform', 'ball_tree', 2)
# Cross-validation mean accuracy: 41.40%
# Elapsed time: 0.03 seconds
#
# Config: (10, 'uniform', 'kd_tree', 1)
# Cross-validation mean accuracy: 41.59%
# Elapsed time: 0.02 seconds
#
# Config: (10, 'uniform', 'kd_tree', 2)
# Cross-validation mean accuracy: 40.51%
# Elapsed time: 0.02 seconds
#
# Config: (10, 'uniform', 'brute', 1)
# Cross-validation mean accuracy: 40.41%
# Elapsed time: 0.03 seconds
#
# Config: (10, 'uniform', 'brute', 2)
# Cross-validation mean accuracy: 39.69%
# Elapsed time: 0.04 seconds
#
# Config: (10, 'distance', 'auto', 1)
# Cross-validation mean accuracy: 38.98%
# Elapsed time: 0.01 seconds
#
# Config: (10, 'distance', 'auto', 2)
# Cross-validation mean accuracy: 38.52%
# Elapsed time: 0.01 seconds
#
# Config: (10, 'distance', 'ball_tree', 1)
# Cross-validation mean accuracy: 40.32%
# Elapsed time: 0.02 seconds
#
# Config: (10, 'distance', 'ball_tree', 2)
# Cross-validation mean accuracy: 39.69%
# Elapsed time: 0.01 seconds
#
# Config: (10, 'distance', 'kd_tree', 1)
# Cross-validation mean accuracy: 39.69%
# Elapsed time: 0.01 seconds
#
# Config: (10, 'distance', 'kd_tree', 2)
# Cross-validation mean accuracy: 40.33%
# Elapsed time: 0.01 seconds
#
# Config: (10, 'distance', 'brute', 1)
# Cross-validation mean accuracy: 40.51%
# Elapsed time: 0.02 seconds
#
# Config: (10, 'distance', 'brute', 2)
# Cross-validation mean accuracy: 37.80%
# Elapsed time: 0.02 seconds
#
# Config: (15, 'uniform', 'auto', 1)
# Cross-validation mean accuracy: 41.13%
# Elapsed time: 0.02 seconds
#
# Config: (15, 'uniform', 'auto', 2)
# Cross-validation mean accuracy: 40.59%
# Elapsed time: 0.02 seconds
#
# Config: (15, 'uniform', 'ball_tree', 1)
# Cross-validation mean accuracy: 43.20%
# Elapsed time: 0.03 seconds
#
# Config: (15, 'uniform', 'ball_tree', 2)
# Cross-validation mean accuracy: 42.39%
# Elapsed time: 0.03 seconds
#
# Config: (15, 'uniform', 'kd_tree', 1)
# Cross-validation mean accuracy: 42.57%
# Elapsed time: 0.02 seconds
#
# Config: (15, 'uniform', 'kd_tree', 2)
# Cross-validation mean accuracy: 43.02%
# Elapsed time: 0.02 seconds
#
# Config: (15, 'uniform', 'brute', 1)
# Cross-validation mean accuracy: 43.65%
# Elapsed time: 0.04 seconds
#
# Config: (15, 'uniform', 'brute', 2)
# Cross-validation mean accuracy: 41.94%
# Elapsed time: 0.04 seconds
#
# Config: (15, 'distance', 'auto', 1)
# Cross-validation mean accuracy: 40.05%
# Elapsed time: 0.01 seconds
#
# Config: (15, 'distance', 'auto', 2)
# Cross-validation mean accuracy: 40.41%
# Elapsed time: 0.01 seconds
#
# Config: (15, 'distance', 'ball_tree', 1)
# Cross-validation mean accuracy: 41.04%
# Elapsed time: 0.02 seconds
#
# Config: (15, 'distance', 'ball_tree', 2)
# Cross-validation mean accuracy: 38.97%
# Elapsed time: 0.02 seconds
#
# Config: (15, 'distance', 'kd_tree', 1)
# Cross-validation mean accuracy: 38.97%
# Elapsed time: 0.01 seconds
#
# Config: (15, 'distance', 'kd_tree', 2)
# Cross-validation mean accuracy: 41.76%
# Elapsed time: 0.01 seconds
#
# Config: (15, 'distance', 'brute', 1)
# Cross-validation mean accuracy: 41.67%
# Elapsed time: 0.02 seconds
#
# Config: (15, 'distance', 'brute', 2)
# Cross-validation mean accuracy: 38.07%
# Elapsed time: 0.02 seconds
#
# Config: (20, 'uniform', 'auto', 1)
# Cross-validation mean accuracy: 44.10%
# Elapsed time: 0.02 seconds
#
# Config: (20, 'uniform', 'auto', 2)
# Cross-validation mean accuracy: 43.56%
# Elapsed time: 0.02 seconds
#
# Config: (20, 'uniform', 'ball_tree', 1)
# Cross-validation mean accuracy: 42.13%
# Elapsed time: 0.03 seconds
#
# Config: (20, 'uniform', 'ball_tree', 2)
# Cross-validation mean accuracy: 44.20%
# Elapsed time: 0.03 seconds
#
# Config: (20, 'uniform', 'kd_tree', 1)
# Cross-validation mean accuracy: 42.31%
# Elapsed time: 0.04 seconds
#
# Config: (20, 'uniform', 'kd_tree', 2)
# Cross-validation mean accuracy: 42.39%
# Elapsed time: 0.03 seconds
#
# Config: (20, 'uniform', 'brute', 1)
# Cross-validation mean accuracy: 43.12%
# Elapsed time: 0.03 seconds
#
# Config: (20, 'uniform', 'brute', 2)
# Cross-validation mean accuracy: 42.30%
# Elapsed time: 0.04 seconds
#
# Config: (20, 'distance', 'auto', 1)
# Cross-validation mean accuracy: 40.15%
# Elapsed time: 0.01 seconds
#
# Config: (20, 'distance', 'auto', 2)
# Cross-validation mean accuracy: 39.52%
# Elapsed time: 0.01 seconds
#
# Config: (20, 'distance', 'ball_tree', 1)
# Cross-validation mean accuracy: 42.12%
# Elapsed time: 0.02 seconds
#
# Config: (20, 'distance', 'ball_tree', 2)
# Cross-validation mean accuracy: 39.69%
# Elapsed time: 0.02 seconds
#
# Config: (20, 'distance', 'kd_tree', 1)
# Cross-validation mean accuracy: 41.58%
# Elapsed time: 0.01 seconds
#
# Config: (20, 'distance', 'kd_tree', 2)
# Cross-validation mean accuracy: 39.60%
# Elapsed time: 0.01 seconds
#
# Config: (20, 'distance', 'brute', 1)
# Cross-validation mean accuracy: 39.33%
# Elapsed time: 0.02 seconds
#
# Config: (20, 'distance', 'brute', 2)
# Cross-validation mean accuracy: 40.41%
# Elapsed time: 0.02 seconds
#
# Config: (25, 'uniform', 'auto', 1)
# Cross-validation mean accuracy: 43.56%
# Elapsed time: 0.03 seconds
#
# Config: (25, 'uniform', 'auto', 2)
# Cross-validation mean accuracy: 40.32%
# Elapsed time: 0.02 seconds
#
# Config: (25, 'uniform', 'ball_tree', 1)
# Cross-validation mean accuracy: 43.65%
# Elapsed time: 0.03 seconds
#
# Config: (25, 'uniform', 'ball_tree', 2)
# Cross-validation mean accuracy: 42.30%
# Elapsed time: 0.04 seconds
#
# Config: (25, 'uniform', 'kd_tree', 1)
# Cross-validation mean accuracy: 42.57%
# Elapsed time: 0.03 seconds
#
# Config: (25, 'uniform', 'kd_tree', 2)
# Cross-validation mean accuracy: 43.92%
# Elapsed time: 0.03 seconds
#
# Config: (25, 'uniform', 'brute', 1)
# Cross-validation mean accuracy: 44.91%
# Elapsed time: 0.03 seconds
#
# Config: (25, 'uniform', 'brute', 2)
# Cross-validation mean accuracy: 42.85%
# Elapsed time: 0.04 seconds
#
# Config: (25, 'distance', 'auto', 1)
# Cross-validation mean accuracy: 40.77%
# Elapsed time: 0.01 seconds
#
# Config: (25, 'distance', 'auto', 2)
# Cross-validation mean accuracy: 40.78%
# Elapsed time: 0.01 seconds
#
# Config: (25, 'distance', 'ball_tree', 1)
# Cross-validation mean accuracy: 41.32%
# Elapsed time: 0.02 seconds
#
# Config: (25, 'distance', 'ball_tree', 2)
# Cross-validation mean accuracy: 39.88%
# Elapsed time: 0.02 seconds
#
# Config: (25, 'distance', 'kd_tree', 1)
# Cross-validation mean accuracy: 41.04%
# Elapsed time: 0.02 seconds
#
# Config: (25, 'distance', 'kd_tree', 2)
# Cross-validation mean accuracy: 41.68%
# Elapsed time: 0.01 seconds
#
# Config: (25, 'distance', 'brute', 1)
# Cross-validation mean accuracy: 42.03%
# Elapsed time: 0.02 seconds
#
# Config: (25, 'distance', 'brute', 2)
# Cross-validation mean accuracy: 40.15%
# Elapsed time: 0.03 seconds
#
# Config: (50, 'uniform', 'auto', 1)
# Cross-validation mean accuracy: 43.75%
# Elapsed time: 0.03 seconds
#
# Config: (50, 'uniform', 'auto', 2)
# Cross-validation mean accuracy: 42.03%
# Elapsed time: 0.03 seconds
#
# Config: (50, 'uniform', 'ball_tree', 1)
# Cross-validation mean accuracy: 43.30%
# Elapsed time: 0.03 seconds
#
# Config: (50, 'uniform', 'ball_tree', 2)
# Cross-validation mean accuracy: 41.49%
# Elapsed time: 0.03 seconds
#
# Config: (50, 'uniform', 'kd_tree', 1)
# Cross-validation mean accuracy: 43.02%
# Elapsed time: 0.03 seconds
#
# Config: (50, 'uniform', 'kd_tree', 2)
# Cross-validation mean accuracy: 42.21%
# Elapsed time: 0.03 seconds
#
# Config: (50, 'uniform', 'brute', 1)
# Cross-validation mean accuracy: 42.75%
# Elapsed time: 0.04 seconds
#
# Config: (50, 'uniform', 'brute', 2)
# Cross-validation mean accuracy: 42.84%
# Elapsed time: 0.04 seconds
#
# Config: (50, 'distance', 'auto', 1)
# Cross-validation mean accuracy: 43.12%
# Elapsed time: 0.02 seconds
#
# Config: (50, 'distance', 'auto', 2)
# Cross-validation mean accuracy: 40.95%
# Elapsed time: 0.02 seconds
#
# Config: (50, 'distance', 'ball_tree', 1)
# Cross-validation mean accuracy: 41.95%
# Elapsed time: 0.02 seconds
#
# Config: (50, 'distance', 'ball_tree', 2)
# Cross-validation mean accuracy: 40.96%
# Elapsed time: 0.02 seconds
#
# Config: (50, 'distance', 'kd_tree', 1)
# Cross-validation mean accuracy: 42.12%
# Elapsed time: 0.02 seconds
#
# Config: (50, 'distance', 'kd_tree', 2)
# Cross-validation mean accuracy: 41.94%
# Elapsed time: 0.02 seconds
#
# Config: (50, 'distance', 'brute', 1)
# Cross-validation mean accuracy: 42.04%
# Elapsed time: 0.02 seconds
#
# Config: (50, 'distance', 'brute', 2)
# Cross-validation mean accuracy: 41.13%
# Elapsed time: 0.03 seconds
#
# Config: (75, 'uniform', 'auto', 1)
# Cross-validation mean accuracy: 41.49%
# Elapsed time: 0.03 seconds
#
# Config: (75, 'uniform', 'auto', 2)
# Cross-validation mean accuracy: 43.92%
# Elapsed time: 0.03 seconds
#
# Config: (75, 'uniform', 'ball_tree', 1)
# Cross-validation mean accuracy: 42.85%
# Elapsed time: 0.04 seconds
#
# Config: (75, 'uniform', 'ball_tree', 2)
# Cross-validation mean accuracy: 43.84%
# Elapsed time: 0.03 seconds
#
# Config: (75, 'uniform', 'kd_tree', 1)
# Cross-validation mean accuracy: 43.02%
# Elapsed time: 0.03 seconds
#
# Config: (75, 'uniform', 'kd_tree', 2)
# Cross-validation mean accuracy: 44.20%
# Elapsed time: 0.03 seconds
#
# Config: (75, 'uniform', 'brute', 1)
# Cross-validation mean accuracy: 44.65%
# Elapsed time: 0.03 seconds
#
# Config: (75, 'uniform', 'brute', 2)
# Cross-validation mean accuracy: 43.74%
# Elapsed time: 0.04 seconds
#
# Config: (75, 'distance', 'auto', 1)
# Cross-validation mean accuracy: 42.75%
# Elapsed time: 0.03 seconds
#
# Config: (75, 'distance', 'auto', 2)
# Cross-validation mean accuracy: 41.67%
# Elapsed time: 0.02 seconds
#
# Config: (75, 'distance', 'ball_tree', 1)
# Cross-validation mean accuracy: 41.58%
# Elapsed time: 0.03 seconds
#
# Config: (75, 'distance', 'ball_tree', 2)
# Cross-validation mean accuracy: 42.03%
# Elapsed time: 0.03 seconds
#
# Config: (75, 'distance', 'kd_tree', 1)
# Cross-validation mean accuracy: 43.03%
# Elapsed time: 0.03 seconds
#
# Config: (75, 'distance', 'kd_tree', 2)
# Cross-validation mean accuracy: 42.12%
# Elapsed time: 0.02 seconds
#
# Config: (75, 'distance', 'brute', 1)
# Cross-validation mean accuracy: 42.04%
# Elapsed time: 0.03 seconds
#
# Config: (75, 'distance', 'brute', 2)
# Cross-validation mean accuracy: 42.49%
# Elapsed time: 0.03 seconds
#
# Config: (100, 'uniform', 'auto', 1)
# Cross-validation mean accuracy: 43.47%
# Elapsed time: 0.04 seconds
#
# Config: (100, 'uniform', 'auto', 2)
# Cross-validation mean accuracy: 43.74%
# Elapsed time: 0.04 seconds
#
# Config: (100, 'uniform', 'ball_tree', 1)
# Cross-validation mean accuracy: 43.30%
# Elapsed time: 0.04 seconds
#
# Config: (100, 'uniform', 'ball_tree', 2)
# Cross-validation mean accuracy: 44.91%
# Elapsed time: 0.04 seconds
#
# Config: (100, 'uniform', 'kd_tree', 1)
# Cross-validation mean accuracy: 44.28%
# Elapsed time: 0.04 seconds
#
# Config: (100, 'uniform', 'kd_tree', 2)
# Cross-validation mean accuracy: 43.92%
# Elapsed time: 0.04 seconds
#
# Config: (100, 'uniform', 'brute', 1)
# Cross-validation mean accuracy: 42.75%
# Elapsed time: 0.04 seconds
#
# Config: (100, 'uniform', 'brute', 2)
# Cross-validation mean accuracy: 45.10%
# Elapsed time: 0.04 seconds
#
# Config: (100, 'distance', 'auto', 1)
# Cross-validation mean accuracy: 42.13%
# Elapsed time: 0.03 seconds
#
# Config: (100, 'distance', 'auto', 2)
# Cross-validation mean accuracy: 41.14%
# Elapsed time: 0.03 seconds
#
# Config: (100, 'distance', 'ball_tree', 1)
# Cross-validation mean accuracy: 42.40%
# Elapsed time: 0.03 seconds
#
# Config: (100, 'distance', 'ball_tree', 2)
# Cross-validation mean accuracy: 41.67%
# Elapsed time: 0.03 seconds
#
# Config: (100, 'distance', 'kd_tree', 1)
# Cross-validation mean accuracy: 42.58%
# Elapsed time: 0.03 seconds
#
# Config: (100, 'distance', 'kd_tree', 2)
# Cross-validation mean accuracy: 42.22%
# Elapsed time: 0.03 seconds
#
# Config: (100, 'distance', 'brute', 1)
# Cross-validation mean accuracy: 41.49%
# Elapsed time: 0.03 seconds
#
# Config: (100, 'distance', 'brute', 2)
# Cross-validation mean accuracy: 43.11%
# Elapsed time: 0.03 seconds
#
# Config: (150, 'uniform', 'auto', 1)
# Cross-validation mean accuracy: 43.74%
# Elapsed time: 0.04 seconds
#
# Config: (150, 'uniform', 'auto', 2)
# Cross-validation mean accuracy: 43.74%
# Elapsed time: 0.04 seconds
#
# Config: (150, 'uniform', 'ball_tree', 1)
# Cross-validation mean accuracy: 43.57%
# Elapsed time: 0.05 seconds
#
# Config: (150, 'uniform', 'ball_tree', 2)
# Cross-validation mean accuracy: 43.03%
# Elapsed time: 0.04 seconds
#
# Config: (150, 'uniform', 'kd_tree', 1)
# Cross-validation mean accuracy: 42.66%
# Elapsed time: 0.04 seconds
#
# Config: (150, 'uniform', 'kd_tree', 2)
# Cross-validation mean accuracy: 43.57%
# Elapsed time: 0.04 seconds
#
# Config: (150, 'uniform', 'brute', 1)
# Cross-validation mean accuracy: 44.20%
# Elapsed time: 0.04 seconds
#
# Config: (150, 'uniform', 'brute', 2)
# Cross-validation mean accuracy: 43.38%
# Elapsed time: 0.04 seconds
#
# Config: (150, 'distance', 'auto', 1)
# Cross-validation mean accuracy: 39.33%
# Elapsed time: 0.04 seconds
#
# Config: (150, 'distance', 'auto', 2)
# Cross-validation mean accuracy: 43.48%
# Elapsed time: 0.04 seconds
#
# Config: (150, 'distance', 'ball_tree', 1)
# Cross-validation mean accuracy: 41.41%
# Elapsed time: 0.04 seconds
#
# Config: (150, 'distance', 'ball_tree', 2)
# Cross-validation mean accuracy: 43.20%
# Elapsed time: 0.04 seconds
#
# Config: (150, 'distance', 'kd_tree', 1)
# Cross-validation mean accuracy: 42.75%
# Elapsed time: 0.04 seconds
#
# Config: (150, 'distance', 'kd_tree', 2)
# Cross-validation mean accuracy: 43.20%
# Elapsed time: 0.04 seconds
#
# Config: (150, 'distance', 'brute', 1)
# Cross-validation mean accuracy: 42.57%
# Elapsed time: 0.04 seconds
#
# Config: (150, 'distance', 'brute', 2)
# Cross-validation mean accuracy: 42.04%
# Elapsed time: 0.04 seconds

# %% [markdown]
# ## Model's paramemters with the best accuracy

# %%
# Output the best model details
print("Best Model Configuration: {}, Cross-validation mean accuracy: {:.2f}%".format(best_config, best_score * 100))
# Optionally save the best model
# best_model_filename = f"{model_directory}/best_knn_model.joblib"
# joblib.dump(best_model, best_model_filename)
best_model.fit(X_train, y_train)
# Find the best parameters
# best_params = results.loc[results['accuracy'].idxmax()]
# print(f"Best parameters: {best_params}")

# # Train the final model with the best parameters
# final_model = KNeighborsClassifier(n_neighbors=best_params['n_neighbors'], 
#                             weights=best_params['weights'], 
#                             algorithm=best_params['algorithm'], 
#                             p=best_params['p'], )

# final_model.fit(X_train, y_train)

# # Save the final model
joblib.dump(best_model, 'models/knn.joblib')
# Out:
# Best Model Configuration: (100, 'uniform', 'brute', 2), Cross-validation mean accuracy: 45.10%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7568\1354467103.py in <module>
#       4 # best_model_filename = f"{model_directory}/best_knn_model.joblib"
#       5 # joblib.dump(best_model, best_model_filename)
# ----> 6 best_model.fit(X_train, y_train)
#       7 # Find the best parameters
#       8 # best_params = results.loc[results['accuracy'].idxmax()]
#
# c:\Users\Howie\miniconda3\envs\wine\lib\site-packages\sklearn\neighbors\_classification.py in fit(self, X, y)
#     196         self.weights = _check_weights(self.weights)
#     197
# --> 198         return self._fit(X, y)
#     199
#     200     def predict(self, X):
#
# c:\Users\Howie\miniconda3\envs\wine\lib\site-packages\sklearn\neighbors\_base.py in _fit(self, X, y)
#     398         if self._get_tags()["requires_y"]:
#     399             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 400                 X, y = self._validate_data(X, y, accept_sparse="csr", multi_output=True)
#     401
#     402             if is_classifier(self):
#
# c:\Users\Howie\miniconda3\envs\wine\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# c:\Users\Howie\miniconda3\envs\wine\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     979     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     980
# --> 981     check_consistent_length(X, y)
#     982
#     983     return X, y
#
# c:\Users\Howie\miniconda3\envs\wine\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
# --> 334             % [int(l) for l in lengths]
#     335         )
#     336
#
# ValueError: Found input variables with inconsistent numbers of samples: [1111, 1119]

# %% [markdown]
# ## Acuracy on the test set

# %%
from data_preprocess import load_test_data
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import joblib

# Load the test data
X_test, y_test = load_test_data('data/test.csv')

features = ['alcohol', 'sulphates', 'total sulfur dioxide', 'volatile acidity']
X_test = X_test[features]

# Preprocess the test data
scaler = StandardScaler()

X_test = scaler.fit_transform(X_test)

# Load the trained model
# Assuming you want to load the best model previously saved
# model_directory = "model_validation"
# best_model_filename = f"{model_directory}/best_knn_model.joblib"
# model = joblib.load(best_model_filename)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate and print the accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy on test data: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy on test data: 58.75%
